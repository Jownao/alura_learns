# %% [markdown]
# # Táticas

# %%
import bs4
import urllib.request as urllib_request
import pandas
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
# Pegar todos links de uma página

for link in soup.find_all('a'):
    print(link.get('href'))

# %% [markdown]
# # Meus testes

# %%
url = 'https://mulvi.com.br/'

html = urlopen(url)
html = html.read()

soup = BeautifulSoup(html, 'html.parser')

# %%
#print(soup.h2.get_text())
teste = soup.h2.get_text()
print(teste)
#print(soup.find('h2', id="conheca-seac").get_text())
# Out:
# Conheça a MULVI

# %%
r = soup.find('div', id="valores")

print(r.find('h2').get_text())
# Out:
# MISSÃO E VALORES DA MULVI

# %%
# outra forma de fazer o código de cima

(soup.find('div', id="valores")).find('h2').get_text()
# Out:
# 'MISSÃO E VALORES DA MULVI'

# %%
soup.find_all('h2')
# Out:
# [<h2>
#  <strong>Conheça a MULVI</strong>
#  </h2>,
#  <h2 class="negativo wow fadeInUp" data-wow-delay=".2s">MISSÃO E VALORES DA MULVI</h2>,
#  <h2>BANESE CARD</h2>,
#  <h2>BANESE ALIMENTAÇÃO/REFEIÇÃO</h2>,
#  <h2>Banese Card Elo Nanquim</h2>,
#  <h2>NOTÍCIAS</h2>,
#  <h2>NOSSOS PARCEIROS</h2>]

# %%
# Out:
# 'MISSÃO E VALORES DA MULVI'

# %% [markdown]
# ## Atividades alura

# %%
# Atividade 1

from urllib.request import urlopen
from bs4 import BeautifulSoup

url = 'https://alura-site-scraping.herokuapp.com/hello-world.php'

response = urlopen(url)
html = response.read()

soup = BeautifulSoup(html, 'html.parser')

soup.find('h1', {'class': 'sub-header'}).get_text()
# Out:
# 'Curso de Web Scraping'

# %%
# Atividade 2

from urllib.request import Request, urlopen

url = 'https://www.alura.com.br'
headers = {'User-Agent': 'Chrome/76.0.3809.100'}

req = Request(url, headers = headers)
response = urlopen(req)
response.read()
